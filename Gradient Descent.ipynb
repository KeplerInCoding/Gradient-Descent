# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dict1= {"Height":[160,163,165,168,170,173,175,178,180,185,188,190,193,195,198,200],
        "Weight":[50,58,59,70,67,70,78,77,79,81,87,83,92,88,99,100]}
df=pd.DataFrame(dict1)
df
# Out:
#     Height  Weight
# 0      160      50
# 1      163      58
# 2      165      59
# 3      168      70
# 4      170      67
# 5      173      70
# 6      175      78
# 7      178      77
# 8      180      79
# 9      185      81
# 10     188      87
# 11     190      83
# 12     193      92
# 13     195      88
# 14     198      99
# 15     200     100

# %%
x= np.array(dict1['Height'])
y= np.array(dict1['Weight'])
#plt.plot(x, y, marker='o', color='blue', markerfacecolor='red',markersize=10)
plt.scatter(x,y,marker='o',color='red')
plt.xlabel("Height(cms)")
plt.ylabel("Weight(kgs)")
plt.title("Gradient descent")
plt.show()

# %%
df.to_csv('height_weight.csv')

# %%
d=pd.read_csv('height_weight.csv')
d
# Out:
#     Unnamed: 0  Height  Weight
# 0            0     160      50
# 1            1     163      58
# 2            2     165      59
# 3            3     168      70
# 4            4     170      67
# 5            5     173      70
# 6            6     175      78
# 7            7     178      77
# 8            8     180      79
# 9            9     185      81
# 10          10     188      87
# 11          11     190      83
# 12          12     193      92
# 13          13     195      88
# 14          14     198      99
# 15          15     200     100

# %%
def gradient_descent(x,y):
    m = b = 0
    i = 100
    n = len(x)
    a = 0.08
    
    for j in range(i):
        y0 = m * x + b
        cost = (1/n) * sum([val**2 for val in (y-y0)])
        dm = -(2/n) * sum(x*(y-y0))
        db = -(2/n) * sum(y-y0)
        m = m - a * dm
        b = b - a * db
        print ("m {}, b {}, cost {}".format(m,b,cost))
x= np.array(d.Height)
y= np.array(d.Weight)
gradient_descent(x,y)
# Out:
# m 2256.54, b 12.38, cost 6182.25
# m -11759254.304000001, b -64988.13819999999, cost 165850207809.11923
# m 61291460774.87867, b 338729538.84215206, cost 4.5056387383674967e+18
# m -319462691098248.3, b -1765522452099.2468, cost 1.2240431120534246e+26
# m 1.66509999458665e+18, b 9202237091680782.0, cost 3.325347696891243e+33
# m -8.678816241236068e+21, b -4.796380096488437e+19, cost 9.033944308276343e+40
# m 4.523563245091543e+25, b 2.4999640631720062e+23, cost 2.4542441032958748e+48
# m -2.3577667579961078e+29, b -1.3030285739295673e+27, cost 6.667424452732555e+55
# m 1.2289126478210603e+33, b 6.791631485784685e+30, cost 1.8113336311248224e+63
# m -6.405325254725908e+36, b -3.539926841327669e+34, cost 4.920834943842801e+70
# m 3.3385767240312057e+40, b 1.8450768520318626e+38, cost 1.3368391183410721e+78
# m -1.7401293609593432e+44, b -9.616889677378196e+41, cost 3.6317796648779966e+85
# m 9.069883495792532e+47, b 5.012504870190969e+45, cost 9.866425475781269e+92
# m -4.727394897922865e+51, b -2.612612384728733e+49, cost 2.680403566619339e+100
# m 2.4640076723448953e+55, b 1.3617430106512602e+53, cost 7.281829977413138e+107
# m -1.2842874226653136e+59, b -7.097662239896698e+56, cost 1.97824866674202e+115
# m -2.2668815494896268e+200, b -1.2528005251924042e+198, cost inf
# m 1.1815415574217728e+204, b 6.529833391638452e+201, cost inf
# m -6.158418168029014e+207, b -3.40347272092723e+205, cost inf
# m 3.209884078480316e+211, b 1.7739543825006012e+209, cost inf
# m -1.6730523189819362e+215, b -9.24618590842049e+212, cost inf
# m 8.720265260719444e+218, b 4.819287051370651e+216, cost inf
# m -4.5451672583427066e+222, b -2.511903601500957e+220, cost inf
# m 2.369027178492753e+226, b 1.3092516872260076e+224, cost inf
# m -1.2347817920530674e+230, b -6.824067529820354e+227, cost inf
# m 6.435916345019883e+233, b 3.556833121232383e+231, cost inf
# m -3.354521379135621e+237, b -1.8538887250180448e+235, cost inf
# m 1.7484400169037906e+241, b 9.662818826760711e+238, cost inf
# m -9.113200207113462e+244, b -5.036444011918374e+242, cost inf
# m 4.749972387500141e+248, b 2.6250899183723874e+246, cost inf
# m -2.475775487122784e+252, b -1.3682465372856474e+250, cost inf
# m 1.2904210303975961e+256, b 7.13155985130942e+253, cost inf
# m -6.725918583302499e+259, b -3.717103937547965e+257, cost inf
# m 3.5056760331374534e+263, b 1.937424907118696e+261, cost inf
# m -1.8272246827109143e+267, b -1.0098225214547022e+265, cost inf
# m 9.523840792898197e+270, b 5.263386059972122e+268, cost inf
# m -4.964006030933306e+274, b -2.743376408004933e+272, cost inf
# m 2.5873338720148465e+278, b 1.4298996938936131e+276, cost inf
# m -1.3485673715059354e+282, b -7.452907769531904e+279, cost inf
# m 7.02898831558292e+285, b 3.884596553055959e+283, cost inf
# m -3.663641712273458e+289, b -2.0247252276089828e+287, cost inf
# m 1.909559383695871e+293, b 1.0553251003868644e+291, cost inf
# m -9.952984833765814e+296, b -5.500554111343478e+294, cost inf
# m 5.1876840252771894e+300, b 2.8669928840625787e+298, cost inf
# m -2.7039190750915367e+304, b -1.4943309402800971e+302, cost inf
# m inf, b 7.788735617348884e+305, cost inf
# m nan, b -inf, cost inf
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# m nan, b nan, cost nan
# C:\Users\user\AppData\Local\Temp/ipykernel_16668/3684094363.py:9: RuntimeWarning: overflow encountered in double_scalars
#   cost = (1/n) * sum([val**2 for val in (y-y0)])
# C:\Users\user\AppData\Local\Temp/ipykernel_16668/3684094363.py:10: RuntimeWarning: overflow encountered in multiply
#   dm = -(2/n) * sum(x*(y-y0))
# C:\Users\user\AppData\Local\Temp/ipykernel_16668/3684094363.py:12: RuntimeWarning: invalid value encountered in double_scalars
#   m = m - a * dm
